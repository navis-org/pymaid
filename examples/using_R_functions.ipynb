# %% [markdown]
# ## Using R functions in Python
# This notebook demonstrates the usage of `nat`, `elmr` or `catnat` in Python. `Pymaid` offers a few wrappers to use specific functions right away but more importantly it converts between R and Python data so that you can use pretty much any function without much effort.
#
# For example, you could:
# 1. load a neuron in Python2
# 2. convert it to R
# 3. use R to prune it and
# 4. convert back to Python
# 5. plot
#
# Tested with pymaid version 0.48

# %%
from pymaid import rmaid, pymaid, plot

remote_instance = pymaid.CatmaidInstance('url','http_user','http_pw','token')
# Out:
# 2017-06-29 17:11:43,655 - pymaid.pymaid - INFO - CATMAID instance created. See help(CatmaidInstance) to learn how to define globally.

# %% [markdown]
# `pymaid.rmaid` provides a function, `data2py`, to convert general R data to Python data. More importantly, there are two functions, `neuron2py` and `neuron2r`, that allow you to convert back and forth between R and Python objects.

# %%
#Load a neuron using PyMaid
neuronlist_py = pymaid.get_neuron(16, remote_instance = remote_instance )

# %%
neuronlist_py.ix[0].head()
# Out:
# neuron_name                             PN glomerulus VA6 017 DB
# skeleton_id                                                   16
# nodes                treenode_id parent_id creator_id       x...
# connectors          treenode_id connector_id relation       x...
# tags           {'160201_projection_uncertain': [1932675, 1286...
# Name: 0, dtype: object

# %%
#Convert to R
neuronlist_r = rmaid.neuron2r( skdata )
neuronlist_r
# Out:
# R object with classes: ('neuronlist', 'list') mapped to:
# <ListVector - Python:0x11ec9be88 / R:0x12393a818>
# [ListVector]
# R object with classes: ('neuronlist', 'list') mapped to:
# <ListVector - Python:0x11ec9be88 / R:0x12393a818>
# [ListVector]

# %% [markdown]
# Let's try it the other way around. `Rmaid` offers a wrapper to initialise R's catmaid library:

# %%
#Here we use credentials stored in the alread existing <remote_instance> but we could also just pass those by hand
#see help(rmaid.init_rcatmaid)
rcatmaid = rmaid.init_rcatmaid( remote_instance = remote_instance )
# Out:
# 2017-06-29 17:12:02,987 - pymaid.rmaid - INFO - Rcatmaid successfully initiated.

# %% [markdown]
# `rcatmaid` behaves pretty much like a normal Python module such as `pymaid`:

# %%
#Check which functions are available
dir(rcatmaid)
# Out:
# ['*_catmaidneuron',
#  '+_catmaidneuron',
#  '___NAMESPACE___',
#  '___S3MethodsTable___',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__rdata__',
#  '__rname__',
#  '__spec__',
#  '__version__',
#  '_env',
#  '_exported_names',
#  '_packageName',
#  '_package_statevars',
#  '_rpy2r',
#  '_symbol_check_after',
#  '_symbol_r2python',
#  '_translation',
#  'as_catmaidmesh',
#  'as_catmaidmesh_catmaidmesh',
#  'as_catmaidmesh_default',
#  'as_catmaidmesh_hxsurf',
#  'as_catmaidmesh_mesh3d',
#  'authname',
#  'authpassword',
#  'catmaid_add_volume',
#  'catmaid_aids',
#  'catmaid_cache_connection',
#  'catmaid_cached_connection',
#  'catmaid_connection',
#  'catmaid_connection_fingerprint',
#  'catmaid_connection_getenv',
#  'catmaid_connection_setenv',
#  'catmaid_connection_unsetenv',
#  'catmaid_entities_from_models',
#  'catmaid_error_check',
#  'catmaid_fetch',
#  'catmaid_get_annotationlist',
#  'catmaid_get_annotations_for_skeletons',
#  'catmaid_get_compact_skeleton',
#  'catmaid_get_connector_table',
#  'catmaid_get_connectors',
#  'catmaid_get_connectors_between',
#  'catmaid_get_contributor_stats',
#  'catmaid_get_label_stats',
#  'catmaid_get_neuronnames',
#  'catmaid_get_review_status',
#  'catmaid_get_treenode_table',
#  'catmaid_get_user_list',
#  'catmaid_last_connection',
#  'catmaid_login',
#  'catmaid_parse_json',
#  'catmaid_parse_url',
#  'catmaid_query_by_annotation',
#  'catmaid_query_by_name',
#  'catmaid_query_connected',
#  'catmaid_remove_annotations_for_skeletons',
#  'catmaid_rename_neuron',
#  'catmaid_set_annotations_for_skeletons',
#  'catmaid_skids',
#  'catmaid_user_history',
#  'catmaid_version',
#  'connectors',
#  'connectors_catmaidneuron',
#  'connectors_neuron',
#  'connectors_neuronlist',
#  'copy_tags_connectors',
#  'get_neuronid_for_skid',
#  'list2df',
#  'nsoma',
#  'plot3d_catmaidneuron',
#  'plot3d_somarad',
#  'process_one_user_history',
#  'query_by_neuron_or_annotation',
#  'read_neuron_catmaid',
#  'read_neurons_catmaid',
#  'server',
#  'somapos_catmaidneuron',
#  'summary_catmaidneuron',
#  'token',
#  'xform_catmaidneuron']

# %% [markdown]
# Note that '.' (dots) from R have been replaced with '_' (underscore). For example `read.neurons.catmaid` is in Python `read_neurons_catmaid`:

# %%
neuron_r = rcatmaid.read_neuron_catmaid(16)
neuron_r
# Out:
# R object with classes: ('catmaidneuron', 'neuron') mapped to:
# <ListVector - Python:0x11ff3aa88 / R:0x126a446b0>
# [IntVe..., IntVe..., IntVe..., ..., ListV..., StrVe..., ListV...]
#   NumPoints: <class 'rpy2.robjects.vectors.IntVector'>
#   R object with classes: ('integer',) mapped to:
# <IntVector - Python:0x11ff61648 / R:0x124719bf8>
# [   10102]
#   StartPoint: <class 'rpy2.robjects.vectors.IntVector'>
#   R object with classes: ('integer',) mapped to:
# <IntVector - Python:0x11ff61348 / R:0x124719c28>
# [    9471]
#   BranchPoints: <class 'rpy2.robjects.vectors.IntVector'>
#   R object with classes: ('integer',) mapped to:
# <IntVector - Python:0x11ff36448 / R:0x11e548e00>
# [       3,       41,       57, ...,    10057,    10077,    10079]
#   ...
# R object with classes: ('catmaidneuron', 'neuron') mapped to:
# <ListVector - Python:0x11ff3aa88 / R:0x126a446b0>
# [IntVe..., IntVe..., IntVe..., ..., ListV..., StrVe..., ListV...]
#   StartPoint: <class 'rpy2.robjects.vectors.StrVector'>
#   R object with classes: ('character',) mapped to:
# <StrVector - Python:0x11ccf9248 / R:0x11e66f5b8>
# ['https://neuropil.janelia.org/tracing/fafb/v13//1...]
# R object with classes: ('catmaidneuron', 'neuron') mapped to:
# <ListVector - Python:0x11ff3aa88 / R:0x126a446b0>
# [IntVe..., IntVe..., IntVe..., ..., ListV..., StrVe..., ListV...]

# %%
#Convert to Python
neuron_py = rmaid.neuron2py(neuron_r)
neuron_py
# Out:
# 2017-06-29 16:59:44,968 - pymaid.rmaid - WARNING - Please provide a remote instance if you want to add neuron name.
#   neuron_name skeleton_id                                              nodes  \
# 0          NA          16        treenode_id parent_id creator_id       x...
#
#                                           connectors  \
# 0       treenode_id connector_id relation       x...
#
#                                                 tags
# 0  {'160201_projection_uncertain': [1932675, 1286...

# %% [markdown]
# Note how `neuron_name` is `NA`? Some data that is stored in Python neurons does not exists in R and vice versa. Nodes, skeleton_id, connectors and tags, however, are always preserved.

# %% [markdown]
# ### Loading other libraries
# Above example uses rcatmaid for which we have a wrapper in `rmaid`. **But even loading other libraries is a piece of cake!**

# %%
from rpy2.robjects.packages import importr

# %%
nat = importr('nat')
dir(nat)
# Out:
# ['*_dotprops',
#  '*_neuron',
#  '*_neuronlist',
#  '+_dotprops',
#  '+_neuron',
#  '+_neuronlist',
#  '-_dotprops',
#  '-_neuron',
#  '-_neuronlist',
#  '/_dotprops',
#  '/_neuron',
#  '/_neuronlist',
#  'DirectPotentialSynapses',
#  'EdgeListFromSegList',
#  'MakeStartEndList',
#  'PotentialSynapses',
#  'PotentialSynapses_default',
#  'PotentialSynapses_dotprops',
#  '[<-_neuronlist',
#  '[[_neuronlistfh',
#  '[_neuronlist',
#  '[_neuronlistfh',
#  '[_reglist',
#  '_ParseAmirameshParameters',
#  '___NAMESPACE___',
#  '___S3MethodsTable___',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__rdata__',
#  '__rname__',
#  '__spec__',
#  '__version__',
#  '_checkLabel',
#  '_env',
#  '_exported_names',
#  '_fileformats',
#  '_onAttach',
#  '_onLoad',
#  '_packageName',
#  '_plotted3d',
#  '_read_amiramesh_bin',
#  '_rpy2r',
#  '_standardNrrdType',
#  '_symbol_check_after',
#  '_symbol_r2python',
#  '_translation',
#  'affmat2cmtkparams',
#  'all_equal_dotprops',
#  'all_equal_im3d',
#  'all_equal_neuron',
#  'amiratype',
#  'as_cmtkreg',
#  'as_cmtkreg_default',
#  'as_cmtkreg_matrix',
#  'as_cmtkreg_reglist',
#  'as_data_frame_morphml_cell',
#  'as_data_frame_neuronlist',
#  'as_directed_usingroot',
#  'as_dotprops',
#  'as_hxsurf',
#  'as_hxsurf_mesh3d',
#  'as_im3d',
#  'as_im3d_im3d',
#  'as_im3d_matrix',
#  'as_list_neuronlistfh',
#  'as_mesh3d_ashape3d',
#  'as_mesh3d_hxsurf',
#  'as_neuron',
#  'as_neuron_data_frame',
#  'as_neuron_default',
#  'as_neuron_morphml_cell',
#  'as_neuron_neuron',
#  'as_neuron_ngraph',
#  'as_neuronlist',
#  'as_neuronlist_default',
#  'as_neuronlist_neuronlistfh',
#  'as_neuronlistfh',
#  'as_neuronlistfh_neuronlist',
#  'as_ngraph',
#  'as_ngraph_data_frame',
#  'as_ngraph_igraph',
#  'as_ngraph_morphml_cell',
#  'as_ngraph_neuron',
#  'as_ngraph_ngraph',
#  'as_seglist',
#  'as_seglist_default',
#  'as_seglist_igraph',
#  'as_seglist_list',
#  'as_seglist_neuron',
#  'as_seglist_seglist',
#  'boundingbox',
#  'boundingbox<-',
#  'boundingbox<-_default',
#  'boundingbox_character',
#  'boundingbox_default',
#  'boundingbox_im3d',
#  'boundingbox_list',
#  'boundingbox_neuron',
#  'boundingbox_shape3d',
#  'branchpoints',
#  'branchpoints_default',
#  'branchpoints_igraph',
#  'branchpoints_neuron',
#  'c_neuronlist',
#  'c_reglist',
#  'clampmax',
#  'cmtk_arg_name',
#  'cmtk_bindir',
#  'cmtk_call',
#  'cmtk_dof2mat',
#  'cmtk_extract_affine',
#  'cmtk_mat2dof',
#  'cmtk_reformatx',
#  'cmtk_statistics',
#  'cmtk_streamxform',
#  'cmtk_system2',
#  'cmtk_targetvolume',
#  'cmtk_targetvolume_character',
#  'cmtk_targetvolume_default',
#  'cmtk_targetvolume_im3d',
#  'cmtk_targetvolume_list',
#  'cmtk_version',
#  'cmtklandmarks',
#  'cmtkparams2affmat',
#  'cmtkreg',
#  'cmtkreglist',
#  'coord2ind',
#  'coord2ind_default',
#  'data_frame<-',
#  'data_frame<-_neuronlist',
#  'decode_rle',
#  'dim_im3d',
#  'dimnames_neuronlist',
#  'dist3D_Segment_to_Segment',
#  'dotprod',
#  'dotprops',
#  'dotprops2swc',
#  'dotprops_character',
#  'dotprops_default',
#  'dotprops_dotprops',
#  'dotprops_im3d',
#  'dotprops_list',
#  'dotprops_neuron',
#  'dotprops_neuronlist',
#  'droplevels_neuronlist',
#  'endpoints',
#  'endpoints_default',
#  'endpoints_igraph',
#  'endpoints_neuron',
#  'fast3dintegertable',
#  'fileformats',
#  'fillMissing',
#  'find_neuron',
#  'find_soma',
#  'flip',
#  'flip_array',
#  'flip_matrix',
#  'flip_vector',
#  'generic_magic_check',
#  'getformatreader',
#  'getformatwriter',
#  'graph_nodes',
#  'head_neuronlist',
#  'ijkpos',
#  'im3d',
#  'im3d2nrrdheader',
#  'image_im3d',
#  'imexpand_grid',
#  'imscalebar',
#  'imslice',
#  'ind2coord',
#  'ind2coord_array',
#  'ind2coord_default',
#  'ind2coord_im3d',
#  'intersect',
#  'intersect_default',
#  'intersect_neuronlist',
#  'invert_reglist',
#  'is_amiramesh',
#  'is_amiramesh_im3d',
#  'is_amiratype',
#  'is_cmtklandmarks',
#  'is_cmtkreg',
#  'is_dotprops',
#  'is_fijilandmarks',
#  'is_fijitraces',
#  'is_hxlineset',
#  'is_hxskel',
#  'is_im3d',
#  'is_neuroml',
#  'is_neuron',
#  'is_neuronlist',
#  'is_neuronlistfh',
#  'is_nrrd',
#  'is_swc',
#  'is_vaa3draw',
#  'makecols',
#  'mask',
#  'mask_im3d',
#  'materials',
#  'materials<-',
#  'materials<-_default',
#  'materials<-_hxsurf',
#  'materials_character',
#  'materials_default',
#  'materials_hxsurf',
#  'mirror',
#  'mirror_character',
#  'mirror_default',
#  'mirror_neuronlist',
#  'ndigest',
#  'ndigest_default',
#  'ndigest_dotprops',
#  'ndigest_neuron',
#  'ndigest_neuronlistfh',
#  'neuron',
#  'neuronlist',
#  'neuronlistfh',
#  'ngraph',
#  'nlapply',
#  'nlscan',
#  'nmapply',
#  'nopen3d',
#  'normalise_swc',
#  'normbyrow',
#  'npop3d',
#  'nrrd_datafiles',
#  'nrrd_voxdims',
#  'nvertices',
#  'nvertices_default',
#  'nvertices_dotprops',
#  'nvertices_neuron',
#  'nvertices_neuronlist',
#  'origin',
#  'pan3d',
#  'plot3d_boundingbox',
#  'plot3d_character',
#  'plot3d_cmtkreg',
#  'plot3d_dotprops',
#  'plot3d_hxsurf',
#  'plot3d_neuron',
#  'plot3d_neuronlist',
#  'plot_neuron',
#  'plot_neuronlist',
#  'pointsinside',
#  'pointsinside_default',
#  'potential_synapses',
#  'potential_synapses_dotprops',
#  'potential_synapses_neuron',
#  'potential_synapses_neuronlist',
#  'process_morphml_cell',
#  'projection',
#  'prune',
#  'prune_default',
#  'prune_dotprops',
#  'prune_edges',
#  'prune_neuron',
#  'prune_neuronlist',
#  'prune_strahler',
#  'prune_vertices',
#  'read_amiramesh',
#  'read_amiramesh_ascii',
#  'read_amiramesh_header',
#  'read_cmtk',
#  'read_cmtkreg',
#  'read_fijixml',
#  'read_hxsurf',
#  'read_im3d',
#  'read_im3d_amiramesh',
#  'read_im3d_nrrd',
#  'read_im3d_vaa3draw',
#  'read_landmarks',
#  'read_landmarks_amira',
#  'read_landmarks_cmtk',
#  'read_landmarks_fiji',
#  'read_morphml',
#  'read_neuron',
#  'read_neuron_fiji',
#  'read_neuron_hxlineset',
#  'read_neuron_hxskel',
#  'read_neuron_neuroml',
#  'read_neuron_swc',
#  'read_neuronlistfh',
#  'read_neurons',
#  'read_ngraph_swc',
#  'read_nrrd',
#  'read_nrrd_header',
#  'read_swc',
#  'read_vaa3draw',
#  'read_zlib',
#  'registerformat',
#  'reglist',
#  'remotesync',
#  'remotesync_default',
#  'remotesync_neuronlistfh',
#  'resample',
#  'resample_neuron',
#  'resample_segment',
#  'restrictToBounds',
#  'rootpoints',
#  'rootpoints_default',
#  'rootpoints_igraph',
#  'rootpoints_neuron',
#  'rowbyrow',
#  'scale_dotprops',
#  'scale_neuron',
#  'seglength',
#  'seglengths',
#  'seglist',
#  'seglist2df',
#  'seglist2swc',
#  'segmentgraph',
#  'setdiff',
#  'setdiff_default',
#  'setdiff_neuronlist',
#  'simplify_reglist',
#  'smooth_neuron',
#  'smooth_segment_gauss',
#  'smooth_segment_spline',
#  'spine',
#  'strahler_order',
#  'sub2ind',
#  'subset_dotprops',
#  'subset_hxsurf',
#  'subset_neuron',
#  'subset_neuronlist',
#  'summary_dotprops',
#  'summary_neuron',
#  'summary_neuronlist',
#  'swapped',
#  'tail_neuronlist',
#  'thetaBetween',
#  'threshold',
#  'threshold_im3d',
#  'union',
#  'union_default',
#  'union_neuronlist',
#  'unlinktempfiles_reglist',
#  'unmask',
#  'voxdims',
#  'voxdims_character',
#  'voxdims_default',
#  'voxdims_im3d',
#  'with_neuronlist',
#  'write_amiramesh',
#  'write_cmtk',
#  'write_cmtk_list',
#  'write_cmtkreg',
#  'write_dotprops_swc',
#  'write_hxsurf',
#  'write_im3d',
#  'write_landmarks',
#  'write_landmarks_amira',
#  'write_landmarks_cmtk',
#  'write_landmarks_fiji',
#  'write_neuron',
#  'write_neuron_hxlineset',
#  'write_neuron_hxskel',
#  'write_neuron_swc',
#  'write_neuronlistfh',
#  'write_neurons',
#  'write_nrrd',
#  'write_nrrd_header',
#  'write_nrrd_header_for_file',
#  'write_vtk',
#  'write_vtk_neuron',
#  'write_zlib',
#  'xform',
#  'xform_character',
#  'xform_data_frame',
#  'xform_default',
#  'xform_dotprops',
#  'xform_list',
#  'xform_neuron',
#  'xform_neuronlist',
#  'xform_shape3d',
#  'xformimage',
#  'xformimage_character',
#  'xformimage_cmtkreg',
#  'xformimage_default',
#  'xformimage_reglist',
#  'xformpoints',
#  'xformpoints_character',
#  'xformpoints_cmtkreg',
#  'xformpoints_default',
#  'xformpoints_reglist',
#  'xyzmatrix',
#  'xyzmatrix<-',
#  'xyzmatrix<-_default',
#  'xyzmatrix<-_dotprops',
#  'xyzmatrix<-_hxsurf',
#  'xyzmatrix<-_igraph',
#  'xyzmatrix<-_neuron',
#  'xyzmatrix<-_neuronlist',
#  'xyzmatrix<-_shape3d',
#  'xyzmatrix_default',
#  'xyzmatrix_dotprops',
#  'xyzmatrix_hxsurf',
#  'xyzmatrix_igraph',
#  'xyzmatrix_mesh3d',
#  'xyzmatrix_neuron',
#  'xyzmatrix_neuronlist',
#  'xyzpos']

# %% [markdown]
# Let us use some basic `nat` function like `prune_strahler`

# %%
pruned = nat.prune_strahler( neuron_r  )

# %%
pruned_py = rmaid.neuron2py( pruned )
pruned_py
# Out:
# 2017-06-29 17:12:34,759 - pymaid.rmaid - WARNING - Neuron has only nodes (no name, skid, connectors or tags).
#   neuron_name skeleton_id                                              nodes  \
# 0          NA          NA       treenode_id parent_id creator_id       x ...
#
#                                           connectors tags
# 0  Empty DataFrame
# Columns: [treenode_id, connect...   {}

# %% [markdown]
# Now we will plot the pruned vs non-pruned neuron.
#
# **Please note that the cell with the 3D plot will be empty when you first open this notebook. You've got to run the code!**

# %%
import plotly.offline as pyoff

#Need to initialize plotly for interactive rendering with Jupyter notebooks
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
import pandas as pd

#First, merge both neurons into one neuronlist
concat = pd.concat( [pruned_py, rmaid.neuron2py( neuron_r )] ).reset_index()

#Give both neurons proper names and generic skeleton IDs
concat.neuron_name = ['pruned','none_pruned']
concat.skeleton_id = [ 1, 2 ]

#Give the pruned neuron a slight offset
concat.ix[0].nodes.x += 10000

fig = plot.plot3d( skdata = concat, backend='plotly', fig_width=1000, downsampling = 1 )
pyoff.iplot(fig)
# Out:
# 2017-06-29 17:20:33,944 - pymaid.rmaid - WARNING - Please provide a remote instance if you want to add neuron name.
# 2017-06-29 17:20:34,018 - pymaid.plot - INFO - Preparing neurons for plotting
# 2017-06-29 17:20:38,910 - pymaid.plot - INFO - Done. Plotted 15858 nodes and 0 connectors
# 2017-06-29 17:20:38,911 - pymaid.plot - INFO - Use plotly.offline.plot(fig, filename="3d_plot.html") to plot. Optimised for Google Chrome.
# <div id="eb9fbdbb-ef27-4c46-8db1-525222343934" style="height: 960px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("eb9fbdbb-ef27-4c46-8db1-525222343934", [{"x": [-481479.0, -481426.0, -481431.0, -481435.0, -481541.0, -481580.0, -481698.0, -481737.0, -481942.0, -482056.0, -482084.0, -482226.0, -482323.0, -482310.0, -482302.0, -482300.0, -482378.0, -482373.0, -482452.0, -482464.0, -482487.0, -482489.0, -482460.0, -482404.0, -482385.0, -482366.0, -482104.0, -482038.0, -482067.0, null, -452603.0, -452824.0, -453046.0, -453489.0, -453795.0, -453769.0, -453760.0, -453721.0, -453643.0, -453982.0, -454120.0, -454157.0, -454324.0, -454527.0, -454611.0, -454778.0, -454931.0, -454945.0, -454973.0, -454987.0, -455001.0, -454854.0, -454974.0, -455094.0, -455214.0, -455414.0, -455656.0, -455737.0, -455782.0, -455916.0, -456309.0, -456358.0, -456400.0, -456403.0, -456444.0, -456508.0, -456646.0, -456717.0, -456697.0, -456934.0, -457183.0, -457340.0, -457587.0, -457749.0, -457856.0, -457877.0, -458323.0, -458508.0, -458688.0, -458758.0, -459038.0, -459081.0, -459139.0, -459351.0, -459617.0, -459725.0, -459733.0, -459757.0, -459736.0, -459915.0, -460248.0, -460364.0, -460595.0, -460716.0, -460837.0, -460898.0, -460974.0, -461000.0, -461022.0, -461044.0, -461089.0, -461111.0, -461250.0, -461335.0, -461420.0, -461591.0, -461776.0, -461862.0, -461947.0, -462177.0, -462248.0, -462354.0, -462362.0, -462394.0, -462449.0, -462365.0, -462661.0, -462966.0, -463350.0, -463455.0, -463564.0, -464197.0, -464654.0, -464801.0, -464784.0, -464773.0, -464825.0, -465072.0, -465158.0, -465417.0, -465589.0, -465373.0, -465169.0, -464965.0, -464907.0, -464868.0, -464802.0, null, -482067.0, -482126.0, -482215.0, -482179.0, -482108.0, -482000.0, -482035.0, -482081.0, -482093.0, -482008.0, -481598.0, -481486.0, -481502.0, -482677.0, null, -471196.0, -471424.0, -471534.0, -471832.0, -471788.0, -471754.0, -472156.0, -472108.0, -472074.0, -472238.0, -472512.0, -472470.0, -472534.0, -472566.0, -473014.0, -472936.0, -472908.0, -472828.0, -472310.0, -472318.0, -472286.0, -472146.0, null, -504560.0, -506002.0, -506420.0, -506486.0, -506474.0, -506466.0, -506922.0, -506970.0, -506975.0, null, -466783.0, -467175.0, -467129.0, -467150.0, -468830.0, -469057.0, -469164.0, -469218.0, -469288.0, -469312.0, -469450.0, -469589.0, -470901.0, -472146.0, null, -472146.0, -473082.0, -473384.0, -474101.0, -475163.0, -474918.0, -474920.0, -474922.0, -474927.0, -474931.0, -474943.0, -474966.0, -474977.0, -474989.0, -475001.0, -475076.0, -475114.0, -475133.0, -475270.0, -475338.0, -475375.0, -475402.0, -475544.0, -475570.0, -475649.0, -475701.0, -476013.0, -476206.0, -476270.0, -476346.0, -476498.0, -476568.0, -476638.0, -476905.0, -477040.0, -477245.0, -477346.0, -477447.0, -477701.0, -477752.0, -477484.0, -477430.0, -477452.0, -477565.0, -477601.0, -477634.0, -477659.0, -477708.0, null, -455547.0, -455975.0, -456116.0, -456275.0, -456438.0, -456666.0, -456888.0, -457078.0, -457310.0, -457472.0, -457620.0, -457713.0, -457838.0, -457901.0, -458013.0, -458154.0, -458337.0, -458493.0, -458555.0, -458778.0, -458989.0, -459125.0, -459379.0, -459781.0, -459911.0, -459735.0, -459860.0, -459737.0, -462300.0, null, -454887.0, -456851.0, -457600.0, -457876.0, -458419.0, -458856.0, -459107.0, -459532.0, -460352.0, -460764.0, -461170.0, -461392.0, -462423.0, -463273.0, -463525.0, -463744.0, -463957.0, -464377.0, -464683.0, -464802.0, null, -463009.0, -463194.0, -463221.0, -463331.0, -463415.0, -463668.0, -463705.0, -463742.0, -463779.0, -463726.0, -465465.0, null, -499892.0, -500085.0, -500283.0, -500710.0, -501138.0, -501563.0, null, -501563.0, -501992.0, -502410.0, -502800.0, -503195.0, null, -555036.0, -555036.0, -555018.0, -554996.0, -554986.0, -554974.0, -554967.0, -554954.0, -554940.0, -554928.0, -554914.0, -554905.0, -554895.0 ...
